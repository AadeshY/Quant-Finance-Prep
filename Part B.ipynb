# %%
import random

class Order:
    def __init__(self, trader_id, otype, price, qty, time):
        self.trader_id = trader_id
        self.otype = otype  
        self.price = price
        self.qty = qty
        self.time = time

class Trader:
    def __init__(self, tid):
        self.tid = tid

    def getorder(self, time, time_left, lob):
        raise NotImplementedError("This method should be overridden by subclasses")

class Trader_ZIP(Trader):
    def __init__(self, tid):
        super().__init__(tid)

    def getorder(self, time, time_left, lob):
       
        otype = random.choice(['Bid', 'Ask'])
        price = random.randint(1, 500)
        qty = random.randint(1, 10)
        return Order(self.tid, otype, price, qty, time)

class LimitOrderBook:
    def __init__(self):
        self.bid_lob = {'best': None, 'worst': 1, 'n': 0, 'lob': []}
        self.ask_lob = {'best': None, 'worst': 500, 'n': 0, 'lob': []}
        self.tape = []

    def add_order(self, order):
        if order.otype == 'Bid':
            self.bid_lob['lob'].append(order)
            self.bid_lob['lob'].sort(key=lambda x: x.price, reverse=True)
            self.bid_lob['n'] += 1
            self.bid_lob['best'] = self.bid_lob['lob'][0].price
        elif order.otype == 'Ask':
            self.ask_lob['lob'].append(order)
            self.ask_lob['lob'].sort(key=lambda x: x.price)
            self.ask_lob['n'] += 1
            self.ask_lob['best'] = self.ask_lob['lob'][0].price

        self.match_orders()

    def match_orders(self):
        while self.bid_lob['best'] is not None and self.ask_lob['best'] is not None and self.bid_lob['best'] >= self.ask_lob['best']:
            bid_order = self.bid_lob['lob'][0]
            ask_order = self.ask_lob['lob'][0]

            trade_qty = min(bid_order.qty, ask_order.qty)
            trade_price = ask_order.price
            trade_time = max(bid_order.time, ask_order.time)

            self.tape.append({'price': trade_price, 'qty': trade_qty, 'time': trade_time})

            bid_order.qty -= trade_qty
            ask_order.qty -= trade_qty

            if bid_order.qty == 0:
                self.bid_lob['lob'].pop(0)
                self.bid_lob['n'] -= 1
                self.bid_lob['best'] = self.bid_lob['lob'][0].price if self.bid_lob['n'] > 0 else None

            if ask_order.qty == 0:
                self.ask_lob['lob'].pop(0)
                self.ask_lob['n'] -= 1
                self.ask_lob['best'] = self.ask_lob['lob'][0].price if self.ask_lob['n'] > 0 else None

    def print_lob(self):
        print("BID LOB:")
        for order in self.bid_lob['lob']:
            print(f"Trader: {order.trader_id}, Price: {order.price}, Qty: {order.qty}, Time: {order.time}")
        print("ASK LOB:")
        for order in self.ask_lob['lob']:
            print(f"Trader: {order.trader_id}, Price: {order.price}, Qty: {order.qty}, Time: {order.time}")

    def print_tape(self):
        print("Tape:")
        for trade in self.tape:
            print(f"Price: {trade['price']}, Qty: {trade['qty']}, Time: {trade['time']}")

def market_session(sess_id, starttime, endtime, trader_spec, order_schedule, dump_flags, verbose):
    
    lob = LimitOrderBook()
    traders = {tid: Trader_ZIP(tid) for tid in trader_spec}

    time = starttime
    while time < endtime:
        time_left = endtime - time

        
        tid = random.choice(list(traders.keys()))
        order = traders[tid].getorder(time, time_left, lob)
        
        if verbose:
            print(f"Trader {tid} generated order: {order.otype} {order.qty} @ {order.price}")

        
        lob.add_order(order)

        time += random.uniform(0.1, 1.0)  

    if dump_flags['dump_lobs']:
        lob.print_lob()
    if dump_flags['dump_tape']:
        lob.print_tape()


trial_id = 1
start_time = 0.0
end_time = 100.0
traders_spec = ['Trader1', 'Trader2', 'Trader3', 'Trader4']
order_sched = {}  
dump_flags = {'dump_lobs': True, 'dump_tape': True}
verbose = True

market_session(trial_id, start_time, end_time, traders_spec, order_sched, dump_flags, verbose)
# Out:
# Trader Trader3 generated order: Ask 9 @ 74
# Trader Trader3 generated order: Bid 10 @ 350
# Trader Trader4 generated order: Bid 10 @ 316
# Trader Trader3 generated order: Ask 5 @ 296
# Trader Trader2 generated order: Ask 10 @ 421
# Trader Trader4 generated order: Bid 4 @ 85
# Trader Trader4 generated order: Ask 2 @ 497
# Trader Trader4 generated order: Bid 6 @ 261
# Trader Trader2 generated order: Ask 7 @ 111
# Trader Trader3 generated order: Bid 5 @ 308
# Trader Trader4 generated order: Ask 8 @ 447
# Trader Trader4 generated order: Ask 3 @ 55
# Trader Trader1 generated order: Bid 10 @ 135
# Trader Trader4 generated order: Bid 4 @ 13
# Trader Trader3 generated order: Bid 4 @ 196
# Trader Trader1 generated order: Ask 10 @ 240
# Trader Trader3 generated order: Ask 1 @ 443
# Trader Trader1 generated order: Ask 2 @ 52
# Trader Trader2 generated order: Bid 10 @ 407
# Trader Trader1 generated order: Bid 2 @ 445
# Trader Trader3 generated order: Bid 6 @ 434
# Trader Trader2 generated order: Bid 7 @ 38
# Trader Trader2 generated order: Bid 7 @ 466
# Trader Trader1 generated order: Ask 8 @ 416
# Trader Trader1 generated order: Bid 10 @ 356
# Trader Trader3 generated order: Ask 7 @ 472
# Trader Trader2 generated order: Bid 7 @ 334
# Trader Trader4 generated order: Bid 9 @ 241
# Trader Trader4 generated order: Bid 1 @ 321
# Trader Trader1 generated order: Ask 8 @ 55
# Trader Trader2 generated order: Bid 5 @ 467
# Trader Trader3 generated order: Ask 7 @ 407
# Trader Trader3 generated order: Bid 7 @ 258
# Trader Trader3 generated order: Bid 9 @ 365
# Trader Trader4 generated order: Ask 6 @ 22
# Trader Trader2 generated order: Ask 3 @ 70
# Trader Trader2 generated order: Bid 8 @ 413
# Trader Trader1 generated order: Bid 3 @ 325
# Trader Trader3 generated order: Bid 10 @ 293
# Trader Trader4 generated order: Bid 7 @ 336
# Trader Trader2 generated order: Bid 8 @ 18
# Trader Trader4 generated order: Bid 3 @ 58
# Trader Trader2 generated order: Ask 8 @ 110
# Trader Trader2 generated order: Ask 2 @ 289
# Trader Trader2 generated order: Bid 10 @ 240
# Trader Trader3 generated order: Bid 9 @ 59
# Trader Trader4 generated order: Bid 9 @ 9
# Trader Trader4 generated order: Bid 2 @ 401
# Trader Trader2 generated order: Ask 5 @ 222
# Trader Trader2 generated order: Ask 2 @ 149
# Trader Trader1 generated order: Ask 5 @ 61
# Trader Trader2 generated order: Ask 3 @ 204
# Trader Trader3 generated order: Ask 9 @ 126
# Trader Trader4 generated order: Bid 7 @ 32
# Trader Trader4 generated order: Ask 5 @ 109
# Trader Trader4 generated order: Ask 1 @ 178
# Trader Trader4 generated order: Bid 10 @ 390
# Trader Trader4 generated order: Ask 5 @ 240
# Trader Trader4 generated order: Ask 2 @ 24
# Trader Trader3 generated order: Ask 8 @ 183
# Trader Trader3 generated order: Ask 10 @ 7
# Trader Trader4 generated order: Ask 10 @ 422
# Trader Trader2 generated order: Ask 6 @ 111
# Trader Trader4 generated order: Bid 4 @ 200
# Trader Trader3 generated order: Bid 9 @ 319
# Trader Trader1 generated order: Ask 3 @ 47
# Trader Trader3 generated order: Ask 9 @ 416
# Trader Trader3 generated order: Ask 2 @ 351
# Trader Trader1 generated order: Ask 6 @ 177
# Trader Trader2 generated order: Bid 2 @ 333
# Trader Trader1 generated order: Ask 7 @ 11
# Trader Trader4 generated order: Ask 10 @ 198
# Trader Trader3 generated order: Ask 7 @ 244
# Trader Trader1 generated order: Ask 10 @ 270
# Trader Trader4 generated order: Ask 2 @ 141
# Trader Trader2 generated order: Bid 9 @ 307
# Trader Trader3 generated order: Bid 2 @ 99
# Trader Trader2 generated order: Ask 2 @ 439
# Trader Trader3 generated order: Bid 1 @ 423
# Trader Trader2 generated order: Bid 1 @ 71
# Trader Trader3 generated order: Bid 2 @ 488
# Trader Trader2 generated order: Bid 6 @ 216
# Trader Trader4 generated order: Ask 5 @ 220
# Trader Trader3 generated order: Bid 7 @ 172
# Trader Trader3 generated order: Ask 5 @ 86
# Trader Trader1 generated order: Ask 7 @ 17
# Trader Trader2 generated order: Bid 1 @ 448
# Trader Trader3 generated order: Ask 4 @ 486
# Trader Trader2 generated order: Bid 7 @ 99
# Trader Trader3 generated order: Bid 2 @ 282
# Trader Trader3 generated order: Bid 1 @ 33
# Trader Trader4 generated order: Ask 1 @ 117
# Trader Trader3 generated order: Bid 2 @ 427
# Trader Trader3 generated order: Bid 9 @ 163
# Trader Trader1 generated order: Ask 4 @ 95
# Trader Trader1 generated order: Bid 7 @ 28
# Trader Trader1 generated order: Bid 3 @ 201
# Trader Trader4 generated order: Ask 10 @ 460
# Trader Trader2 generated order: Bid 7 @ 143
# Trader Trader1 generated order: Ask 8 @ 445
# Trader Trader1 generated order: Bid 2 @ 282
# Trader Trader2 generated order: Bid 2 @ 335
# Trader Trader4 generated order: Ask 1 @ 125
# Trader Trader1 generated order: Bid 9 @ 145
# Trader Trader4 generated order: Bid 1 @ 129
# Trader Trader2 generated order: Ask 4 @ 488
# Trader Trader3 generated order: Bid 3 @ 158
# Trader Trader1 generated order: Bid 7 @ 46
# Trader Trader3 generated order: Ask 8 @ 354
# Trader Trader3 generated order: Ask 10 @ 148
# Trader Trader2 generated order: Bid 2 @ 437
# Trader Trader3 generated order: Bid 4 @ 421
# Trader Trader1 generated order: Ask 9 @ 247
# Trader Trader1 generated order: Bid 10 @ 2
# Trader Trader4 generated order: Bid 4 @ 183
# Trader Trader1 generated order: Bid 5 @ 129
# Trader Trader1 generated order: Bid 1 @ 248
# Trader Trader3 generated order: Bid 4 @ 409
# Trader Trader2 generated order: Bid 5 @ 192
# Trader Trader4 generated order: Bid 1 @ 157
# Trader Trader3 generated order: Bid 1 @ 413
# Trader Trader1 generated order: Bid 5 @ 127
# Trader Trader4 generated order: Ask 8 @ 128
# Trader Trader1 generated order: Bid 4 @ 114
# Trader Trader1 generated order: Bid 6 @ 368
# Trader Trader4 generated order: Ask 10 @ 152
# Trader Trader1 generated order: Bid 8 @ 38
# Trader Trader2 generated order: Ask 4 @ 479
# Trader Trader4 generated order: Bid 6 @ 425
# Trader Trader2 generated order: Ask 5 @ 496
# Trader Trader1 generated order: Bid 2 @ 83
# Trader Trader2 generated order: Ask 8 @ 312
# Trader Trader4 generated order: Bid 8 @ 248
# Trader Trader1 generated order: Bid 4 @ 243
# Trader Trader2 generated order: Ask 2 @ 20
# Trader Trader3 generated order: Bid 2 @ 2
# Trader Trader2 generated order: Ask 10 @ 310
# Trader Trader2 generated order: Ask 1 @ 90
# Trader Trader4 generated order: Bid 8 @ 234
# Trader Trader1 generated order: Ask 4 @ 386
# Trader Trader2 generated order: Bid 8 @ 435
# Trader Trader1 generated order: Bid 6 @ 138
# Trader Trader2 generated order: Ask 7 @ 298
# Trader Trader1 generated order: Ask 3 @ 158
# Trader Trader4 generated order: Bid 1 @ 267
# Trader Trader4 generated order: Bid 2 @ 298
# Trader Trader4 generated order: Ask 9 @ 48
# Trader Trader3 generated order: Ask 8 @ 6
# Trader Trader3 generated order: Ask 9 @ 120
# Trader Trader3 generated order: Ask 8 @ 71
# Trader Trader1 generated order: Bid 9 @ 303
# Trader Trader1 generated order: Ask 4 @ 222
# Trader Trader2 generated order: Ask 4 @ 114
# Trader Trader3 generated order: Bid 10 @ 201
# Trader Trader2 generated order: Ask 7 @ 299
# Trader Trader1 generated order: Ask 10 @ 146
# Trader Trader1 generated order: Bid 7 @ 148
# Trader Trader3 generated order: Bid 7 @ 91
# Trader Trader1 generated order: Ask 10 @ 457
# Trader Trader3 generated order: Ask 2 @ 193
# Trader Trader3 generated order: Ask 2 @ 42
# Trader Trader3 generated order: Ask 5 @ 273
# Trader Trader1 generated order: Bid 6 @ 329
# Trader Trader4 generated order: Bid 7 @ 265
# Trader Trader1 generated order: Ask 9 @ 11
# Trader Trader1 generated order: Bid 6 @ 491
# Trader Trader1 generated order: Ask 4 @ 401
# Trader Trader4 generated order: Bid 1 @ 106
# Trader Trader2 generated order: Ask 8 @ 123
# Trader Trader2 generated order: Ask 7 @ 352
# Trader Trader1 generated order: Ask 5 @ 279
# Trader Trader3 generated order: Bid 4 @ 241
# Trader Trader1 generated order: Ask 9 @ 113
# Trader Trader4 generated order: Bid 6 @ 422
# Trader Trader3 generated order: Ask 6 @ 419
# Trader Trader4 generated order: Ask 9 @ 385
# Trader Trader1 generated order: Bid 5 @ 103
# Trader Trader1 generated order: Bid 8 @ 229
# Trader Trader3 generated order: Ask 3 @ 270
# Trader Trader4 generated order: Bid 2 @ 277
# Trader Trader2 generated order: Bid 6 @ 264
# Trader Trader1 generated order: Ask 5 @ 113
# Trader Trader2 generated order: Bid 6 @ 111
# Trader Trader2 generated order: Bid 1 @ 158
# Trader Trader3 generated order: Ask 4 @ 443
# Trader Trader1 generated order: Ask 7 @ 410
# Trader Trader3 generated order: Bid 1 @ 148
# BID LOB:
# Trader: Trader2, Price: 264, Qty: 1, Time: 96.40861698273946
# Trader: Trader1, Price: 229, Qty: 8, Time: 95.03254313524059
# Trader: Trader2, Price: 158, Qty: 1, Time: 97.63286934862872
# Trader: Trader3, Price: 148, Qty: 1, Time: 99.74379098902229
# Trader: Trader1, Price: 129, Qty: 3, Time: 64.19202871296862
# Trader: Trader1, Price: 127, Qty: 5, Time: 66.97578550050572
# Trader: Trader1, Price: 114, Qty: 4, Time: 68.03792142671776
# Trader: Trader2, Price: 111, Qty: 6, Time: 97.02968505913483
# Trader: Trader4, Price: 106, Qty: 1, Time: 90.54280451750128
# Trader: Trader1, Price: 103, Qty: 5, Time: 94.09519673855924
# Trader: Trader3, Price: 99, Qty: 2, Time: 42.13371315986541
# Trader: Trader2, Price: 99, Qty: 7, Time: 50.38220782231461
# Trader: Trader3, Price: 91, Qty: 7, Time: 86.4624142709678
# Trader: Trader4, Price: 85, Qty: 4, Time: 2.912505223021562
# Trader: Trader1, Price: 83, Qty: 2, Time: 72.5387528369619
# Trader: Trader2, Price: 71, Qty: 1, Time: 44.347741971440115
# Trader: Trader3, Price: 59, Qty: 9, Time: 24.690376424437723
# Trader: Trader4, Price: 58, Qty: 3, Time: 21.62743737762696
# Trader: Trader1, Price: 46, Qty: 7, Time: 59.55813530129148
# Trader: Trader2, Price: 38, Qty: 7, Time: 10.537648726307044
# Trader: Trader1, Price: 38, Qty: 8, Time: 70.56387393926884
# Trader: Trader3, Price: 33, Qty: 1, Time: 51.57823768697542
# Trader: Trader4, Price: 32, Qty: 7, Time: 29.3088567023246
# Trader: Trader1, Price: 28, Qty: 7, Time: 53.57056463662707
# Trader: Trader2, Price: 18, Qty: 8, Time: 21.301003008463017
# Trader: Trader4, Price: 13, Qty: 4, Time: 7.072908983285093
# Trader: Trader4, Price: 9, Qty: 9, Time: 24.88016272534045
# Trader: Trader1, Price: 2, Qty: 10, Time: 62.9805705653199
# Trader: Trader3, Price: 2, Qty: 2, Time: 74.91405264962134
# ASK LOB:
# Trader: Trader3, Price: 270, Qty: 1, Time: 95.48905449344156
# Trader: Trader2, Price: 299, Qty: 1, Time: 84.88655135448538
# Trader: Trader2, Price: 310, Qty: 2, Time: 75.03532866900987
# Trader: Trader2, Price: 312, Qty: 8, Time: 73.17529966244713
# Trader: Trader2, Price: 352, Qty: 7, Time: 90.92301196664907
# Trader: Trader3, Price: 354, Qty: 8, Time: 60.06852123292792
# Trader: Trader4, Price: 385, Qty: 9, Time: 93.39569750095644
# Trader: Trader1, Price: 386, Qty: 4, Time: 76.91413624599323
# Trader: Trader1, Price: 401, Qty: 4, Time: 90.36495744590523
# Trader: Trader1, Price: 410, Qty: 7, Time: 99.04961545442967
# Trader: Trader1, Price: 416, Qty: 3, Time: 12.106779208887499
# Trader: Trader3, Price: 416, Qty: 9, Time: 36.987639823169715
# Trader: Trader3, Price: 419, Qty: 6, Time: 92.83238392052988
# Trader: Trader4, Price: 422, Qty: 10, Time: 35.016433626272885
# Trader: Trader2, Price: 439, Qty: 2, Time: 42.930704964214264
# Trader: Trader3, Price: 443, Qty: 4, Time: 98.56524739749929
# Trader: Trader1, Price: 445, Qty: 8, Time: 55.8122319705998
# Trader: Trader4, Price: 447, Qty: 4, Time: 5.548045908210343
# Trader: Trader1, Price: 457, Qty: 10, Time: 86.72759625341017
# Trader: Trader4, Price: 460, Qty: 10, Time: 54.63848728851935
# Trader: Trader3, Price: 472, Qty: 7, Time: 13.344424853376534
# Trader: Trader2, Price: 479, Qty: 4, Time: 70.77005137321783
# Trader: Trader3, Price: 486, Qty: 4, Time: 49.43243137270108
# Trader: Trader2, Price: 488, Qty: 4, Time: 58.69732149122933
# Trader: Trader2, Price: 496, Qty: 5, Time: 72.19789807163926
# Trader: Trader4, Price: 497, Qty: 2, Time: 3.040309489493462
# Tape:
# Price: 74, Qty: 9, Time: 0.23328996622353898
# Price: 296, Qty: 1, Time: 1.2882508055102972
# Price: 296, Qty: 4, Time: 1.2882508055102972
# Price: 111, Qty: 6, Time: 4.859096872598572
# Price: 111, Qty: 1, Time: 4.859096872598572
# Price: 55, Qty: 3, Time: 5.973747868896464
# Price: 240, Qty: 2, Time: 7.634281376047743
# Price: 240, Qty: 5, Time: 7.634281376047743
# Price: 52, Qty: 2, Time: 9.047456947848424
# Price: 240, Qty: 3, Time: 9.190660191312581
# Price: 421, Qty: 2, Time: 9.578021481659889
# Price: 421, Qty: 6, Time: 10.27249607982069
# Price: 421, Qty: 2, Time: 11.123410249870856
# Price: 443, Qty: 1, Time: 11.123410249870856
# Price: 447, Qty: 4, Time: 11.123410249870856
# Price: 55, Qty: 7, Time: 15.270764478141711
# Price: 55, Qty: 1, Time: 15.270764478141711
# Price: 416, Qty: 5, Time: 15.883094626715536
# Price: 22, Qty: 6, Time: 17.776947970892834
# Price: 70, Qty: 3, Time: 18.447350335308126
# Price: 407, Qty: 7, Time: 18.764134705697124
# Price: 110, Qty: 1, Time: 22.343341736114233
# Price: 110, Qty: 7, Time: 22.343341736114233
# Price: 289, Qty: 2, Time: 23.14369434287556
# Price: 222, Qty: 2, Time: 26.53271321818844
# Price: 222, Qty: 3, Time: 26.53271321818844
# Price: 149, Qty: 2, Time: 26.752137272768028
# Price: 61, Qty: 2, Time: 27.62698075414363
# Price: 61, Qty: 3, Time: 27.62698075414363
# Price: 204, Qty: 3, Time: 27.75014483758638
# Price: 126, Qty: 1, Time: 28.67978803472868
# Price: 126, Qty: 3, Time: 28.67978803472868
# Price: 126, Qty: 1, Time: 28.67978803472868
# Price: 126, Qty: 4, Time: 28.67978803472868
# Price: 109, Qty: 5, Time: 29.465951791570777
# Price: 178, Qty: 1, Time: 30.305922766613428
# Price: 240, Qty: 5, Time: 31.889508518865217
# Price: 24, Qty: 2, Time: 32.57587694101597
# Price: 183, Qty: 3, Time: 33.22491118814056
# Price: 183, Qty: 5, Time: 33.22491118814056
# Price: 7, Qty: 2, Time: 34.05673956719919
# Price: 7, Qty: 8, Time: 34.05673956719919
# Price: 111, Qty: 1, Time: 35.157889646462245
# Price: 111, Qty: 5, Time: 35.157889646462245
# Price: 47, Qty: 3, Time: 36.57117018112638
# Price: 177, Qty: 6, Time: 38.588464425844705
# Price: 11, Qty: 2, Time: 39.501238005200335
# Price: 11, Qty: 5, Time: 39.501238005200335
# Price: 198, Qty: 4, Time: 39.9008247089006
# Price: 141, Qty: 2, Time: 41.32982123717079
# Price: 198, Qty: 6, Time: 41.92260288101665
# Price: 244, Qty: 3, Time: 41.92260288101665
# Price: 244, Qty: 1, Time: 43.4008664386927
# Price: 244, Qty: 2, Time: 44.706746748324825
# Price: 86, Qty: 5, Time: 46.926599862056875
# Price: 17, Qty: 1, Time: 47.64440681754531
# Price: 17, Qty: 6, Time: 47.64440681754531
# Price: 220, Qty: 1, Time: 48.495149893761855
# Price: 220, Qty: 2, Time: 50.8488036363336
# Price: 117, Qty: 1, Time: 52.12300822528682
# Price: 220, Qty: 2, Time: 52.84570761300181
# Price: 95, Qty: 4, Time: 53.25851596857751
# Price: 244, Qty: 1, Time: 56.59569237271751
# Price: 270, Qty: 1, Time: 56.59569237271751
# Price: 270, Qty: 2, Time: 56.81540270674602
# Price: 125, Qty: 1, Time: 56.95711093094338
# Price: 148, Qty: 2, Time: 60.79040800058243
# Price: 148, Qty: 5, Time: 60.79040800058243
# Price: 148, Qty: 3, Time: 60.79040800058243
# Price: 270, Qty: 2, Time: 61.13326408337169
# Price: 270, Qty: 4, Time: 61.97564018708157
# Price: 247, Qty: 1, Time: 64.48469349702398
# Price: 247, Qty: 4, Time: 64.72245063212176
# Price: 247, Qty: 1, Time: 66.80638070800731
# Price: 128, Qty: 5, Time: 67.52322725174014
# Price: 128, Qty: 3, Time: 67.52322725174014
# Price: 247, Qty: 3, Time: 68.94819701962905
# Price: 270, Qty: 1, Time: 68.94819701962905
# Price: 351, Qty: 2, Time: 68.94819701962905
# Price: 152, Qty: 1, Time: 69.57424233866307
# Price: 152, Qty: 1, Time: 69.57424233866307
# Price: 152, Qty: 6, Time: 71.5692423566595
# Price: 152, Qty: 2, Time: 73.57485608718997
# Price: 20, Qty: 2, Time: 74.3541748333501
# Price: 90, Qty: 1, Time: 75.78721743040632
# Price: 310, Qty: 8, Time: 77.17922335299441
# Price: 158, Qty: 3, Time: 79.41856790043282
# Price: 298, Qty: 2, Time: 80.10157149491664
# Price: 48, Qty: 1, Time: 80.47088123079615
# Price: 48, Qty: 4, Time: 80.47088123079615
# Price: 48, Qty: 4, Time: 80.47088123079615
# Price: 6, Qty: 4, Time: 81.13393398387355
# Price: 6, Qty: 4, Time: 81.13393398387355
# Price: 120, Qty: 5, Time: 82.11332788865722
# Price: 120, Qty: 4, Time: 82.11332788865722
# Price: 71, Qty: 3, Time: 82.28460903951436
# Price: 71, Qty: 5, Time: 82.28460903951436
# Price: 298, Qty: 5, Time: 82.68050920126792
# Price: 222, Qty: 4, Time: 83.6571645071368
# Price: 114, Qty: 1, Time: 83.88369486998909
# Price: 114, Qty: 3, Time: 83.88369486998909
# Price: 146, Qty: 10, Time: 85.48790401677051
# Price: 42, Qty: 2, Time: 87.76957515865335
# Price: 193, Qty: 2, Time: 88.26165758531005
# Price: 273, Qty: 4, Time: 88.26165758531005
# Price: 11, Qty: 7, Time: 88.7354259433303
# Price: 11, Qty: 2, Time: 88.7354259433303
# Price: 273, Qty: 1, Time: 89.55380878932264
# Price: 299, Qty: 5, Time: 89.55380878932264
# Price: 123, Qty: 3, Time: 90.80508750847585
# Price: 123, Qty: 5, Time: 90.80508750847585
# Price: 113, Qty: 4, Time: 92.29512420562224
# Price: 113, Qty: 2, Time: 92.29512420562224
# Price: 113, Qty: 1, Time: 92.29512420562224
# Price: 113, Qty: 2, Time: 92.29512420562224
# Price: 279, Qty: 5, Time: 92.55419677462712
# Price: 299, Qty: 1, Time: 92.55419677462712
# Price: 270, Qty: 2, Time: 95.74672474663521
# Price: 113, Qty: 5, Time: 96.89145867345158

# %% [markdown]
# # Explanation

# %% [markdown]
# The code represents a simplified market simulation where traders generate buy (Bid) and sell (Ask) orders, which are processed by a Limit Order Book (LOB). The key components include the Order class, representing market orders with attributes like trader ID, order type, price, quantity, and time of creation, and the Trader class, serving as the base for different trader types, with the getorder method designed for specific trading strategies. The Trader_ZIP subclass of Trader is meant to implement the ZIP (Zero-Intelligence Plus) trading strategy but currently generates random orders instead. The LimitOrderBook class manages buy and sell orders, maintaining lists for bids and asks, processing orders to match and execute trades, and recording completed trades in the tape. The market_session function sets up and runs a simulated trading session by initializing the LOB and traders, generating random orders, processing them, and advancing the simulation time. The dump_flags control whether the LOB and trade tape are printed at the end of the session, while the verbose flag controls the printing of order details during the session. The code executes a single market session with four traders generating and processing random orders through the LOB.

# %% [markdown]
# # Output

# %% [markdown]
# The simulation output provides insights into the market's behavior during the session, starting with a list of generated orders that specify the trader ID, order type (Bid or Ask), quantity, and price. For example, an order like "Trader3 generated order: Ask 5 @ 288" indicates that Trader3 placed an Ask order to sell 5 units at a price of 288. The Limit Order Book (LOB) output reveals the state of active buy and sell orders at the session's end, with Bid orders sorted by descending price and Ask orders by ascending price. For instance, the highest Bid from Trader1 is for 1 unit at 118, while the lowest Ask from Trader2 is for 3 units at 167. The tape logs executed trades, such as one at a price of 288 for 5 units early in the session. The randomness in order generation reflects the simple random strategy used by the traders, resulting in a variety of bids and asks with significant gaps that can cause market inefficiencies. Although the LOB effectively manages order matching, not all orders are immediately matched due to random pricing, leaving a mix of unmatched bids and asks at the session's end. The market behavior observed demonstrates inefficiency due to the non-strategic, random actions of the traders, offering a baseline understanding of how more sophisticated traders, like a potential ZIPSH trader, might need to adapt to succeed in this noisy environment. This output sets the stage for further experiments, such as introducing adaptive strategies to enhance market efficiency.

# %%
import random
import math



class Trader_ZIP:
    def __init__(self, tid, balance):
        self.tid = tid
        self.balance = balance
        self.offer_price = None
        self.limit_price = random.randint(50, 250)  
        self.job = random.choice(['Bid', 'Ask'])  
        self.active = False
        self.ga_params = {'mutation_rate': 0.1, 'crossover_rate': 0.7}  # GA params
        self.genome = {'margin': random.uniform(-0.05, 0.05)}
    
    def getorder(self, time, time_left, lob):
        print(f"Trader {self.tid}: Job = {self.job}, Best Bid = {lob['best_bid']}, Best Ask = {lob['best_ask']}, Limit Price = {self.limit_price}")
        
        if self.job == 'Bid':
            self.offer_price = lob['best_bid'] + 1
            if self.offer_price > self.limit_price:
                self.offer_price = self.limit_price
        elif self.job == 'Ask':
            self.offer_price = lob['best_ask'] - 1
            if self.offer_price < self.limit_price:
                self.offer_price = self.limit_price

        print(f"Trader {self.tid} generated order: Price = {self.offer_price}, Qty = 1")
        return {'tid': self.tid, 'price': self.offer_price, 'qty': 1}

    def adapt(self, success):
        if success:
            self.genome['margin'] += self.genome['margin'] * 0.1
        else:
            self.genome['margin'] -= self.genome['margin'] * 0.1
        
  
        self.genome['margin'] = min(max(self.genome['margin'], -0.05), 0.05)

    def genetic_algorithm(self, population):
        
        offspring = []
        for i in range(len(population) // 2):
            parent1 = population[random.randint(0, len(population) - 1)]
            parent2 = population[random.randint(0, len(population) - 1)]
            child = {'margin': (parent1['margin'] + parent2['margin']) / 2}
            if random.random() < self.ga_params['mutation_rate']:
                child['margin'] += random.uniform(-0.01, 0.01)
            offspring.append(child)
        return offspring



def market_session(sess_id, start_time, end_time, traders_spec, order_schedule, dump_flags, verbose):
    time = start_time
    tape = []
    traders = {}
    for s in traders_spec['sellers']:
        for i in range(s[1]):
            traders['S' + str(i)] = Trader_ZIP('S' + str(i), balance=0)

    for b in traders_spec['buyers']:
        for i in range(b[1]):
            traders['B' + str(i)] = Trader_ZIP('B' + str(i), balance=0)

    while time < end_time:
        time += random.uniform(0.01, 1.0)
        if time > end_time:
            break
        
        for tid in traders:
            trader = traders[tid]
            lob = {'best_bid': random.randint(50, 150), 'best_ask': random.randint(150, 250)}
            order = trader.getorder(time, end_time - time, lob)
            if order:
                tape.append({'time': time, 'tid': tid, 'price': order['price'], 'qty': order['qty']})
                trader.adapt(success=True)  

    if dump_flags and dump_flags.get('dump_tape', False):
        for trade in tape:
            print(f"Price: {trade['price']}, Qty: {trade['qty']}, Time: {trade['time']}")
    
    return tape



supply_schedule = [{'from': 0, 'to': 100, 'ranges': [(50, 100)]}]
demand_schedule = [{'from': 0, 'to': 100, 'ranges': [(150, 200)]}]

order_sched = {'sup': supply_schedule, 'dem': demand_schedule,
               'interval': 30, 'timemode': 'drip-poisson'}



traders_spec = {'sellers': [('ZIP', 10)], 'buyers': [('ZIC', 5)]}



dump_flags = {'dump_tape': True}

market_session(sess_id='test', start_time=0, end_time=100,
               traders_spec=traders_spec, order_schedule=order_sched,
               dump_flags=dump_flags, verbose=True)
# Out:
# Trader S0: Job = Ask, Best Bid = 80, Best Ask = 169, Limit Price = 147
# Trader S0 generated order: Price = 168, Qty = 1
# Trader S1: Job = Ask, Best Bid = 141, Best Ask = 164, Limit Price = 68
# Trader S1 generated order: Price = 163, Qty = 1
# Trader S2: Job = Bid, Best Bid = 118, Best Ask = 186, Limit Price = 231
# Trader S2 generated order: Price = 119, Qty = 1
# Trader S3: Job = Bid, Best Bid = 52, Best Ask = 196, Limit Price = 80
# Trader S3 generated order: Price = 53, Qty = 1
# Trader S4: Job = Ask, Best Bid = 78, Best Ask = 225, Limit Price = 78
# Trader S4 generated order: Price = 224, Qty = 1
# Trader S5: Job = Ask, Best Bid = 126, Best Ask = 156, Limit Price = 68
# Trader S5 generated order: Price = 155, Qty = 1
# Trader S6: Job = Ask, Best Bid = 71, Best Ask = 210, Limit Price = 119
# Trader S6 generated order: Price = 209, Qty = 1
# Trader S7: Job = Bid, Best Bid = 110, Best Ask = 247, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 146, Best Ask = 172, Limit Price = 199
# Trader S8 generated order: Price = 147, Qty = 1
# Trader S9: Job = Ask, Best Bid = 93, Best Ask = 214, Limit Price = 62
# Trader S9 generated order: Price = 213, Qty = 1
# Trader B0: Job = Bid, Best Bid = 137, Best Ask = 158, Limit Price = 204
# Trader B0 generated order: Price = 138, Qty = 1
# Trader B1: Job = Ask, Best Bid = 149, Best Ask = 207, Limit Price = 59
# Trader B1 generated order: Price = 206, Qty = 1
# Trader B2: Job = Bid, Best Bid = 109, Best Ask = 187, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 50, Best Ask = 181, Limit Price = 173
# Trader B3 generated order: Price = 51, Qty = 1
# Trader B4: Job = Bid, Best Bid = 63, Best Ask = 202, Limit Price = 136
# Trader B4 generated order: Price = 64, Qty = 1
# Trader S0: Job = Ask, Best Bid = 77, Best Ask = 164, Limit Price = 147
# Trader S0 generated order: Price = 163, Qty = 1
# Trader S1: Job = Ask, Best Bid = 125, Best Ask = 215, Limit Price = 68
# Trader S1 generated order: Price = 214, Qty = 1
# Trader S2: Job = Bid, Best Bid = 141, Best Ask = 167, Limit Price = 231
# Trader S2 generated order: Price = 142, Qty = 1
# Trader S3: Job = Bid, Best Bid = 86, Best Ask = 208, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 85, Best Ask = 246, Limit Price = 78
# Trader S4 generated order: Price = 245, Qty = 1
# Trader S5: Job = Ask, Best Bid = 128, Best Ask = 185, Limit Price = 68
# Trader S5 generated order: Price = 184, Qty = 1
# Trader S6: Job = Ask, Best Bid = 110, Best Ask = 185, Limit Price = 119
# Trader S6 generated order: Price = 184, Qty = 1
# Trader S7: Job = Bid, Best Bid = 50, Best Ask = 154, Limit Price = 65
# Trader S7 generated order: Price = 51, Qty = 1
# Trader S8: Job = Bid, Best Bid = 125, Best Ask = 214, Limit Price = 199
# Trader S8 generated order: Price = 126, Qty = 1
# Trader S9: Job = Ask, Best Bid = 59, Best Ask = 198, Limit Price = 62
# Trader S9 generated order: Price = 197, Qty = 1
# Trader B0: Job = Bid, Best Bid = 120, Best Ask = 191, Limit Price = 204
# Trader B0 generated order: Price = 121, Qty = 1
# Trader B1: Job = Ask, Best Bid = 71, Best Ask = 243, Limit Price = 59
# Trader B1 generated order: Price = 242, Qty = 1
# Trader B2: Job = Bid, Best Bid = 91, Best Ask = 233, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 95, Best Ask = 186, Limit Price = 173
# Trader B3 generated order: Price = 96, Qty = 1
# Trader B4: Job = Bid, Best Bid = 95, Best Ask = 218, Limit Price = 136
# Trader B4 generated order: Price = 96, Qty = 1
# Trader S0: Job = Ask, Best Bid = 92, Best Ask = 150, Limit Price = 147
# Trader S0 generated order: Price = 149, Qty = 1
# Trader S1: Job = Ask, Best Bid = 74, Best Ask = 224, Limit Price = 68
# Trader S1 generated order: Price = 223, Qty = 1
# Trader S2: Job = Bid, Best Bid = 127, Best Ask = 231, Limit Price = 231
# Trader S2 generated order: Price = 128, Qty = 1
# Trader S3: Job = Bid, Best Bid = 78, Best Ask = 247, Limit Price = 80
# Trader S3 generated order: Price = 79, Qty = 1
# Trader S4: Job = Ask, Best Bid = 91, Best Ask = 183, Limit Price = 78
# Trader S4 generated order: Price = 182, Qty = 1
# Trader S5: Job = Ask, Best Bid = 149, Best Ask = 231, Limit Price = 68
# Trader S5 generated order: Price = 230, Qty = 1
# Trader S6: Job = Ask, Best Bid = 51, Best Ask = 168, Limit Price = 119
# Trader S6 generated order: Price = 167, Qty = 1
# Trader S7: Job = Bid, Best Bid = 67, Best Ask = 189, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 86, Best Ask = 227, Limit Price = 199
# Trader S8 generated order: Price = 87, Qty = 1
# Trader S9: Job = Ask, Best Bid = 118, Best Ask = 231, Limit Price = 62
# Trader S9 generated order: Price = 230, Qty = 1
# Trader B0: Job = Bid, Best Bid = 53, Best Ask = 210, Limit Price = 204
# Trader B0 generated order: Price = 54, Qty = 1
# Trader B1: Job = Ask, Best Bid = 56, Best Ask = 213, Limit Price = 59
# Trader B1 generated order: Price = 212, Qty = 1
# Trader B2: Job = Bid, Best Bid = 89, Best Ask = 153, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 120, Best Ask = 233, Limit Price = 173
# Trader B3 generated order: Price = 121, Qty = 1
# Trader B4: Job = Bid, Best Bid = 76, Best Ask = 188, Limit Price = 136
# Trader B4 generated order: Price = 77, Qty = 1
# Trader S0: Job = Ask, Best Bid = 58, Best Ask = 178, Limit Price = 147
# Trader S0 generated order: Price = 177, Qty = 1
# Trader S1: Job = Ask, Best Bid = 58, Best Ask = 229, Limit Price = 68
# Trader S1 generated order: Price = 228, Qty = 1
# Trader S2: Job = Bid, Best Bid = 86, Best Ask = 181, Limit Price = 231
# Trader S2 generated order: Price = 87, Qty = 1
# Trader S3: Job = Bid, Best Bid = 123, Best Ask = 196, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 125, Best Ask = 220, Limit Price = 78
# Trader S4 generated order: Price = 219, Qty = 1
# Trader S5: Job = Ask, Best Bid = 142, Best Ask = 205, Limit Price = 68
# Trader S5 generated order: Price = 204, Qty = 1
# Trader S6: Job = Ask, Best Bid = 134, Best Ask = 247, Limit Price = 119
# Trader S6 generated order: Price = 246, Qty = 1
# Trader S7: Job = Bid, Best Bid = 52, Best Ask = 240, Limit Price = 65
# Trader S7 generated order: Price = 53, Qty = 1
# Trader S8: Job = Bid, Best Bid = 90, Best Ask = 155, Limit Price = 199
# Trader S8 generated order: Price = 91, Qty = 1
# Trader S9: Job = Ask, Best Bid = 59, Best Ask = 227, Limit Price = 62
# Trader S9 generated order: Price = 226, Qty = 1
# Trader B0: Job = Bid, Best Bid = 52, Best Ask = 219, Limit Price = 204
# Trader B0 generated order: Price = 53, Qty = 1
# Trader B1: Job = Ask, Best Bid = 93, Best Ask = 229, Limit Price = 59
# Trader B1 generated order: Price = 228, Qty = 1
# Trader B2: Job = Bid, Best Bid = 107, Best Ask = 227, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 129, Best Ask = 241, Limit Price = 173
# Trader B3 generated order: Price = 130, Qty = 1
# Trader B4: Job = Bid, Best Bid = 133, Best Ask = 161, Limit Price = 136
# Trader B4 generated order: Price = 134, Qty = 1
# Trader S0: Job = Ask, Best Bid = 103, Best Ask = 211, Limit Price = 147
# Trader S0 generated order: Price = 210, Qty = 1
# Trader S1: Job = Ask, Best Bid = 96, Best Ask = 180, Limit Price = 68
# Trader S1 generated order: Price = 179, Qty = 1
# Trader S2: Job = Bid, Best Bid = 117, Best Ask = 250, Limit Price = 231
# Trader S2 generated order: Price = 118, Qty = 1
# Trader S3: Job = Bid, Best Bid = 132, Best Ask = 223, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 135, Best Ask = 228, Limit Price = 78
# Trader S4 generated order: Price = 227, Qty = 1
# Trader S5: Job = Ask, Best Bid = 116, Best Ask = 173, Limit Price = 68
# Trader S5 generated order: Price = 172, Qty = 1
# Trader S6: Job = Ask, Best Bid = 78, Best Ask = 234, Limit Price = 119
# Trader S6 generated order: Price = 233, Qty = 1
# Trader S7: Job = Bid, Best Bid = 116, Best Ask = 224, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 91, Best Ask = 177, Limit Price = 199
# Trader S8 generated order: Price = 92, Qty = 1
# Trader S9: Job = Ask, Best Bid = 123, Best Ask = 197, Limit Price = 62
# Trader S9 generated order: Price = 196, Qty = 1
# Trader B0: Job = Bid, Best Bid = 137, Best Ask = 153, Limit Price = 204
# Trader B0 generated order: Price = 138, Qty = 1
# Trader B1: Job = Ask, Best Bid = 79, Best Ask = 246, Limit Price = 59
# Trader B1 generated order: Price = 245, Qty = 1
# Trader B2: Job = Bid, Best Bid = 102, Best Ask = 216, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 111, Best Ask = 196, Limit Price = 173
# Trader B3 generated order: Price = 112, Qty = 1
# Trader B4: Job = Bid, Best Bid = 109, Best Ask = 223, Limit Price = 136
# Trader B4 generated order: Price = 110, Qty = 1
# Trader S0: Job = Ask, Best Bid = 118, Best Ask = 214, Limit Price = 147
# Trader S0 generated order: Price = 213, Qty = 1
# Trader S1: Job = Ask, Best Bid = 130, Best Ask = 241, Limit Price = 68
# Trader S1 generated order: Price = 240, Qty = 1
# Trader S2: Job = Bid, Best Bid = 58, Best Ask = 226, Limit Price = 231
# Trader S2 generated order: Price = 59, Qty = 1
# Trader S3: Job = Bid, Best Bid = 107, Best Ask = 215, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 124, Best Ask = 243, Limit Price = 78
# Trader S4 generated order: Price = 242, Qty = 1
# Trader S5: Job = Ask, Best Bid = 75, Best Ask = 165, Limit Price = 68
# Trader S5 generated order: Price = 164, Qty = 1
# Trader S6: Job = Ask, Best Bid = 81, Best Ask = 215, Limit Price = 119
# Trader S6 generated order: Price = 214, Qty = 1
# Trader S7: Job = Bid, Best Bid = 54, Best Ask = 192, Limit Price = 65
# Trader S7 generated order: Price = 55, Qty = 1
# Trader S8: Job = Bid, Best Bid = 101, Best Ask = 191, Limit Price = 199
# Trader S8 generated order: Price = 102, Qty = 1
# Trader S9: Job = Ask, Best Bid = 99, Best Ask = 244, Limit Price = 62
# Trader S9 generated order: Price = 243, Qty = 1
# Trader B0: Job = Bid, Best Bid = 143, Best Ask = 205, Limit Price = 204
# Trader B0 generated order: Price = 144, Qty = 1
# Trader B1: Job = Ask, Best Bid = 141, Best Ask = 160, Limit Price = 59
# Trader B1 generated order: Price = 159, Qty = 1
# Trader B2: Job = Bid, Best Bid = 52, Best Ask = 238, Limit Price = 65
# Trader B2 generated order: Price = 53, Qty = 1
# Trader B3: Job = Bid, Best Bid = 150, Best Ask = 173, Limit Price = 173
# Trader B3 generated order: Price = 151, Qty = 1
# Trader B4: Job = Bid, Best Bid = 120, Best Ask = 207, Limit Price = 136
# Trader B4 generated order: Price = 121, Qty = 1
# Trader S0: Job = Ask, Best Bid = 83, Best Ask = 185, Limit Price = 147
# Trader S0 generated order: Price = 184, Qty = 1
# Trader S1: Job = Ask, Best Bid = 80, Best Ask = 157, Limit Price = 68
# Trader S1 generated order: Price = 156, Qty = 1
# Trader S2: Job = Bid, Best Bid = 122, Best Ask = 154, Limit Price = 231
# Trader S2 generated order: Price = 123, Qty = 1
# Trader S3: Job = Bid, Best Bid = 131, Best Ask = 225, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 52, Best Ask = 201, Limit Price = 78
# Trader S4 generated order: Price = 200, Qty = 1
# Trader S5: Job = Ask, Best Bid = 69, Best Ask = 180, Limit Price = 68
# Trader S5 generated order: Price = 179, Qty = 1
# Trader S6: Job = Ask, Best Bid = 126, Best Ask = 226, Limit Price = 119
# Trader S6 generated order: Price = 225, Qty = 1
# Trader S7: Job = Bid, Best Bid = 88, Best Ask = 152, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 118, Best Ask = 158, Limit Price = 199
# Trader S8 generated order: Price = 119, Qty = 1
# Trader S9: Job = Ask, Best Bid = 102, Best Ask = 219, Limit Price = 62
# Trader S9 generated order: Price = 218, Qty = 1
# Trader B0: Job = Bid, Best Bid = 104, Best Ask = 219, Limit Price = 204
# Trader B0 generated order: Price = 105, Qty = 1
# Trader B1: Job = Ask, Best Bid = 103, Best Ask = 150, Limit Price = 59
# Trader B1 generated order: Price = 149, Qty = 1
# Trader B2: Job = Bid, Best Bid = 132, Best Ask = 240, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 64, Best Ask = 222, Limit Price = 173
# Trader B3 generated order: Price = 65, Qty = 1
# Trader B4: Job = Bid, Best Bid = 71, Best Ask = 206, Limit Price = 136
# Trader B4 generated order: Price = 72, Qty = 1
# Trader S0: Job = Ask, Best Bid = 132, Best Ask = 202, Limit Price = 147
# Trader S0 generated order: Price = 201, Qty = 1
# Trader S1: Job = Ask, Best Bid = 115, Best Ask = 240, Limit Price = 68
# Trader S1 generated order: Price = 239, Qty = 1
# Trader S2: Job = Bid, Best Bid = 96, Best Ask = 205, Limit Price = 231
# Trader S2 generated order: Price = 97, Qty = 1
# Trader S3: Job = Bid, Best Bid = 76, Best Ask = 198, Limit Price = 80
# Trader S3 generated order: Price = 77, Qty = 1
# Trader S4: Job = Ask, Best Bid = 122, Best Ask = 239, Limit Price = 78
# Trader S4 generated order: Price = 238, Qty = 1
# Trader S5: Job = Ask, Best Bid = 57, Best Ask = 246, Limit Price = 68
# Trader S5 generated order: Price = 245, Qty = 1
# Trader S6: Job = Ask, Best Bid = 78, Best Ask = 225, Limit Price = 119
# Trader S6 generated order: Price = 224, Qty = 1
# Trader S7: Job = Bid, Best Bid = 120, Best Ask = 182, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 63, Best Ask = 247, Limit Price = 199
# Trader S8 generated order: Price = 64, Qty = 1
# Trader S9: Job = Ask, Best Bid = 67, Best Ask = 236, Limit Price = 62
# Trader S9 generated order: Price = 235, Qty = 1
# Trader B0: Job = Bid, Best Bid = 67, Best Ask = 166, Limit Price = 204
# Trader B0 generated order: Price = 68, Qty = 1
# Trader B1: Job = Ask, Best Bid = 56, Best Ask = 224, Limit Price = 59
# Trader B1 generated order: Price = 223, Qty = 1
# Trader B2: Job = Bid, Best Bid = 102, Best Ask = 184, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 79, Best Ask = 157, Limit Price = 173
# Trader B3 generated order: Price = 80, Qty = 1
# Trader B4: Job = Bid, Best Bid = 87, Best Ask = 222, Limit Price = 136
# Trader B4 generated order: Price = 88, Qty = 1
# Trader S0: Job = Ask, Best Bid = 61, Best Ask = 201, Limit Price = 147
# Trader S0 generated order: Price = 200, Qty = 1
# Trader S1: Job = Ask, Best Bid = 107, Best Ask = 160, Limit Price = 68
# Trader S1 generated order: Price = 159, Qty = 1
# Trader S2: Job = Bid, Best Bid = 114, Best Ask = 226, Limit Price = 231
# Trader S2 generated order: Price = 115, Qty = 1
# Trader S3: Job = Bid, Best Bid = 118, Best Ask = 155, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 67, Best Ask = 161, Limit Price = 78
# Trader S4 generated order: Price = 160, Qty = 1
# Trader S5: Job = Ask, Best Bid = 118, Best Ask = 158, Limit Price = 68
# Trader S5 generated order: Price = 157, Qty = 1
# Trader S6: Job = Ask, Best Bid = 93, Best Ask = 177, Limit Price = 119
# Trader S6 generated order: Price = 176, Qty = 1
# Trader S7: Job = Bid, Best Bid = 144, Best Ask = 161, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 54, Best Ask = 209, Limit Price = 199
# Trader S8 generated order: Price = 55, Qty = 1
# Trader S9: Job = Ask, Best Bid = 58, Best Ask = 197, Limit Price = 62
# Trader S9 generated order: Price = 196, Qty = 1
# Trader B0: Job = Bid, Best Bid = 116, Best Ask = 219, Limit Price = 204
# Trader B0 generated order: Price = 117, Qty = 1
# Trader B1: Job = Ask, Best Bid = 57, Best Ask = 247, Limit Price = 59
# Trader B1 generated order: Price = 246, Qty = 1
# Trader B2: Job = Bid, Best Bid = 147, Best Ask = 210, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 51, Best Ask = 198, Limit Price = 173
# Trader B3 generated order: Price = 52, Qty = 1
# Trader B4: Job = Bid, Best Bid = 105, Best Ask = 187, Limit Price = 136
# Trader B4 generated order: Price = 106, Qty = 1
# Trader S0: Job = Ask, Best Bid = 120, Best Ask = 235, Limit Price = 147
# Trader S0 generated order: Price = 234, Qty = 1
# Trader S1: Job = Ask, Best Bid = 108, Best Ask = 171, Limit Price = 68
# Trader S1 generated order: Price = 170, Qty = 1
# Trader S2: Job = Bid, Best Bid = 136, Best Ask = 245, Limit Price = 231
# Trader S2 generated order: Price = 137, Qty = 1
# Trader S3: Job = Bid, Best Bid = 80, Best Ask = 160, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 146, Best Ask = 230, Limit Price = 78
# Trader S4 generated order: Price = 229, Qty = 1
# Trader S5: Job = Ask, Best Bid = 135, Best Ask = 229, Limit Price = 68
# Trader S5 generated order: Price = 228, Qty = 1
# Trader S6: Job = Ask, Best Bid = 84, Best Ask = 250, Limit Price = 119
# Trader S6 generated order: Price = 249, Qty = 1
# Trader S7: Job = Bid, Best Bid = 82, Best Ask = 235, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 123, Best Ask = 193, Limit Price = 199
# Trader S8 generated order: Price = 124, Qty = 1
# Trader S9: Job = Ask, Best Bid = 70, Best Ask = 164, Limit Price = 62
# Trader S9 generated order: Price = 163, Qty = 1
# Trader B0: Job = Bid, Best Bid = 107, Best Ask = 233, Limit Price = 204
# Trader B0 generated order: Price = 108, Qty = 1
# Trader B1: Job = Ask, Best Bid = 81, Best Ask = 234, Limit Price = 59
# Trader B1 generated order: Price = 233, Qty = 1
# Trader B2: Job = Bid, Best Bid = 53, Best Ask = 240, Limit Price = 65
# Trader B2 generated order: Price = 54, Qty = 1
# Trader B3: Job = Bid, Best Bid = 135, Best Ask = 182, Limit Price = 173
# Trader B3 generated order: Price = 136, Qty = 1
# Trader B4: Job = Bid, Best Bid = 75, Best Ask = 183, Limit Price = 136
# Trader B4 generated order: Price = 76, Qty = 1
# Trader S0: Job = Ask, Best Bid = 54, Best Ask = 209, Limit Price = 147
# Trader S0 generated order: Price = 208, Qty = 1
# Trader S1: Job = Ask, Best Bid = 56, Best Ask = 245, Limit Price = 68
# Trader S1 generated order: Price = 244, Qty = 1
# Trader S2: Job = Bid, Best Bid = 74, Best Ask = 183, Limit Price = 231
# Trader S2 generated order: Price = 75, Qty = 1
# Trader S3: Job = Bid, Best Bid = 90, Best Ask = 174, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 101, Best Ask = 241, Limit Price = 78
# Trader S4 generated order: Price = 240, Qty = 1
# Trader S5: Job = Ask, Best Bid = 104, Best Ask = 219, Limit Price = 68
# Trader S5 generated order: Price = 218, Qty = 1
# Trader S6: Job = Ask, Best Bid = 127, Best Ask = 230, Limit Price = 119
# Trader S6 generated order: Price = 229, Qty = 1
# Trader S7: Job = Bid, Best Bid = 71, Best Ask = 238, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 81, Best Ask = 209, Limit Price = 199
# Trader S8 generated order: Price = 82, Qty = 1
# Trader S9: Job = Ask, Best Bid = 76, Best Ask = 250, Limit Price = 62
# Trader S9 generated order: Price = 249, Qty = 1
# Trader B0: Job = Bid, Best Bid = 55, Best Ask = 188, Limit Price = 204
# Trader B0 generated order: Price = 56, Qty = 1
# Trader B1: Job = Ask, Best Bid = 140, Best Ask = 247, Limit Price = 59
# Trader B1 generated order: Price = 246, Qty = 1
# Trader B2: Job = Bid, Best Bid = 99, Best Ask = 214, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 66, Best Ask = 204, Limit Price = 173
# Trader B3 generated order: Price = 67, Qty = 1
# Trader B4: Job = Bid, Best Bid = 149, Best Ask = 234, Limit Price = 136
# Trader B4 generated order: Price = 136, Qty = 1
# Trader S0: Job = Ask, Best Bid = 81, Best Ask = 205, Limit Price = 147
# Trader S0 generated order: Price = 204, Qty = 1
# Trader S1: Job = Ask, Best Bid = 69, Best Ask = 250, Limit Price = 68
# Trader S1 generated order: Price = 249, Qty = 1
# Trader S2: Job = Bid, Best Bid = 130, Best Ask = 223, Limit Price = 231
# Trader S2 generated order: Price = 131, Qty = 1
# Trader S3: Job = Bid, Best Bid = 88, Best Ask = 236, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 72, Best Ask = 184, Limit Price = 78
# Trader S4 generated order: Price = 183, Qty = 1
# Trader S5: Job = Ask, Best Bid = 144, Best Ask = 195, Limit Price = 68
# Trader S5 generated order: Price = 194, Qty = 1
# Trader S6: Job = Ask, Best Bid = 71, Best Ask = 190, Limit Price = 119
# Trader S6 generated order: Price = 189, Qty = 1
# Trader S7: Job = Bid, Best Bid = 140, Best Ask = 216, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 145, Best Ask = 209, Limit Price = 199
# Trader S8 generated order: Price = 146, Qty = 1
# Trader S9: Job = Ask, Best Bid = 92, Best Ask = 175, Limit Price = 62
# Trader S9 generated order: Price = 174, Qty = 1
# Trader B0: Job = Bid, Best Bid = 87, Best Ask = 183, Limit Price = 204
# Trader B0 generated order: Price = 88, Qty = 1
# Trader B1: Job = Ask, Best Bid = 128, Best Ask = 238, Limit Price = 59
# Trader B1 generated order: Price = 237, Qty = 1
# Trader B2: Job = Bid, Best Bid = 65, Best Ask = 232, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 68, Best Ask = 223, Limit Price = 173
# Trader B3 generated order: Price = 69, Qty = 1
# Trader B4: Job = Bid, Best Bid = 147, Best Ask = 238, Limit Price = 136
# Trader B4 generated order: Price = 136, Qty = 1
# Trader S0: Job = Ask, Best Bid = 144, Best Ask = 235, Limit Price = 147
# Trader S0 generated order: Price = 234, Qty = 1
# Trader S1: Job = Ask, Best Bid = 119, Best Ask = 221, Limit Price = 68
# Trader S1 generated order: Price = 220, Qty = 1
# Trader S2: Job = Bid, Best Bid = 115, Best Ask = 246, Limit Price = 231
# Trader S2 generated order: Price = 116, Qty = 1
# Trader S3: Job = Bid, Best Bid = 70, Best Ask = 195, Limit Price = 80
# Trader S3 generated order: Price = 71, Qty = 1
# Trader S4: Job = Ask, Best Bid = 131, Best Ask = 227, Limit Price = 78
# Trader S4 generated order: Price = 226, Qty = 1
# Trader S5: Job = Ask, Best Bid = 71, Best Ask = 163, Limit Price = 68
# Trader S5 generated order: Price = 162, Qty = 1
# Trader S6: Job = Ask, Best Bid = 123, Best Ask = 249, Limit Price = 119
# Trader S6 generated order: Price = 248, Qty = 1
# Trader S7: Job = Bid, Best Bid = 90, Best Ask = 215, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 77, Best Ask = 196, Limit Price = 199
# Trader S8 generated order: Price = 78, Qty = 1
# Trader S9: Job = Ask, Best Bid = 150, Best Ask = 183, Limit Price = 62
# Trader S9 generated order: Price = 182, Qty = 1
# Trader B0: Job = Bid, Best Bid = 135, Best Ask = 177, Limit Price = 204
# Trader B0 generated order: Price = 136, Qty = 1
# Trader B1: Job = Ask, Best Bid = 52, Best Ask = 210, Limit Price = 59
# Trader B1 generated order: Price = 209, Qty = 1
# Trader B2: Job = Bid, Best Bid = 70, Best Ask = 165, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 133, Best Ask = 163, Limit Price = 173
# Trader B3 generated order: Price = 134, Qty = 1
# Trader B4: Job = Bid, Best Bid = 141, Best Ask = 209, Limit Price = 136
# Trader B4 generated order: Price = 136, Qty = 1
# Trader S0: Job = Ask, Best Bid = 119, Best Ask = 224, Limit Price = 147
# Trader S0 generated order: Price = 223, Qty = 1
# Trader S1: Job = Ask, Best Bid = 132, Best Ask = 196, Limit Price = 68
# Trader S1 generated order: Price = 195, Qty = 1
# Trader S2: Job = Bid, Best Bid = 91, Best Ask = 202, Limit Price = 231
# Trader S2 generated order: Price = 92, Qty = 1
# Trader S3: Job = Bid, Best Bid = 113, Best Ask = 220, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 77, Best Ask = 188, Limit Price = 78
# Trader S4 generated order: Price = 187, Qty = 1
# Trader S5: Job = Ask, Best Bid = 88, Best Ask = 241, Limit Price = 68
# Trader S5 generated order: Price = 240, Qty = 1
# Trader S6: Job = Ask, Best Bid = 84, Best Ask = 207, Limit Price = 119
# Trader S6 generated order: Price = 206, Qty = 1
# Trader S7: Job = Bid, Best Bid = 52, Best Ask = 241, Limit Price = 65
# Trader S7 generated order: Price = 53, Qty = 1
# Trader S8: Job = Bid, Best Bid = 60, Best Ask = 153, Limit Price = 199
# Trader S8 generated order: Price = 61, Qty = 1
# Trader S9: Job = Ask, Best Bid = 146, Best Ask = 168, Limit Price = 62
# Trader S9 generated order: Price = 167, Qty = 1
# Trader B0: Job = Bid, Best Bid = 59, Best Ask = 238, Limit Price = 204
# Trader B0 generated order: Price = 60, Qty = 1
# Trader B1: Job = Ask, Best Bid = 117, Best Ask = 242, Limit Price = 59
# Trader B1 generated order: Price = 241, Qty = 1
# Trader B2: Job = Bid, Best Bid = 102, Best Ask = 237, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 67, Best Ask = 236, Limit Price = 173
# Trader B3 generated order: Price = 68, Qty = 1
# Trader B4: Job = Bid, Best Bid = 110, Best Ask = 231, Limit Price = 136
# Trader B4 generated order: Price = 111, Qty = 1
# Trader S0: Job = Ask, Best Bid = 138, Best Ask = 242, Limit Price = 147
# Trader S0 generated order: Price = 241, Qty = 1
# Trader S1: Job = Ask, Best Bid = 60, Best Ask = 236, Limit Price = 68
# Trader S1 generated order: Price = 235, Qty = 1
# Trader S2: Job = Bid, Best Bid = 77, Best Ask = 156, Limit Price = 231
# Trader S2 generated order: Price = 78, Qty = 1
# Trader S3: Job = Bid, Best Bid = 118, Best Ask = 214, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 74, Best Ask = 179, Limit Price = 78
# Trader S4 generated order: Price = 178, Qty = 1
# Trader S5: Job = Ask, Best Bid = 90, Best Ask = 209, Limit Price = 68
# Trader S5 generated order: Price = 208, Qty = 1
# Trader S6: Job = Ask, Best Bid = 143, Best Ask = 232, Limit Price = 119
# Trader S6 generated order: Price = 231, Qty = 1
# Trader S7: Job = Bid, Best Bid = 71, Best Ask = 244, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 114, Best Ask = 192, Limit Price = 199
# Trader S8 generated order: Price = 115, Qty = 1
# Trader S9: Job = Ask, Best Bid = 140, Best Ask = 155, Limit Price = 62
# Trader S9 generated order: Price = 154, Qty = 1
# Trader B0: Job = Bid, Best Bid = 101, Best Ask = 223, Limit Price = 204
# Trader B0 generated order: Price = 102, Qty = 1
# Trader B1: Job = Ask, Best Bid = 109, Best Ask = 224, Limit Price = 59
# Trader B1 generated order: Price = 223, Qty = 1
# Trader B2: Job = Bid, Best Bid = 60, Best Ask = 175, Limit Price = 65
# Trader B2 generated order: Price = 61, Qty = 1
# Trader B3: Job = Bid, Best Bid = 97, Best Ask = 207, Limit Price = 173
# Trader B3 generated order: Price = 98, Qty = 1
# Trader B4: Job = Bid, Best Bid = 130, Best Ask = 245, Limit Price = 136
# Trader B4 generated order: Price = 131, Qty = 1
# Trader S0: Job = Ask, Best Bid = 97, Best Ask = 239, Limit Price = 147
# Trader S0 generated order: Price = 238, Qty = 1
# Trader S1: Job = Ask, Best Bid = 111, Best Ask = 180, Limit Price = 68
# Trader S1 generated order: Price = 179, Qty = 1
# Trader S2: Job = Bid, Best Bid = 53, Best Ask = 160, Limit Price = 231
# Trader S2 generated order: Price = 54, Qty = 1
# Trader S3: Job = Bid, Best Bid = 52, Best Ask = 182, Limit Price = 80
# Trader S3 generated order: Price = 53, Qty = 1
# Trader S4: Job = Ask, Best Bid = 61, Best Ask = 165, Limit Price = 78
# Trader S4 generated order: Price = 164, Qty = 1
# Trader S5: Job = Ask, Best Bid = 86, Best Ask = 238, Limit Price = 68
# Trader S5 generated order: Price = 237, Qty = 1
# Trader S6: Job = Ask, Best Bid = 121, Best Ask = 232, Limit Price = 119
# Trader S6 generated order: Price = 231, Qty = 1
# Trader S7: Job = Bid, Best Bid = 76, Best Ask = 197, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 132, Best Ask = 205, Limit Price = 199
# Trader S8 generated order: Price = 133, Qty = 1
# Trader S9: Job = Ask, Best Bid = 90, Best Ask = 223, Limit Price = 62
# Trader S9 generated order: Price = 222, Qty = 1
# Trader B0: Job = Bid, Best Bid = 73, Best Ask = 182, Limit Price = 204
# Trader B0 generated order: Price = 74, Qty = 1
# Trader B1: Job = Ask, Best Bid = 94, Best Ask = 169, Limit Price = 59
# Trader B1 generated order: Price = 168, Qty = 1
# Trader B2: Job = Bid, Best Bid = 134, Best Ask = 244, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 86, Best Ask = 158, Limit Price = 173
# Trader B3 generated order: Price = 87, Qty = 1
# Trader B4: Job = Bid, Best Bid = 82, Best Ask = 181, Limit Price = 136
# Trader B4 generated order: Price = 83, Qty = 1
# Trader S0: Job = Ask, Best Bid = 124, Best Ask = 167, Limit Price = 147
# Trader S0 generated order: Price = 166, Qty = 1
# Trader S1: Job = Ask, Best Bid = 75, Best Ask = 171, Limit Price = 68
# Trader S1 generated order: Price = 170, Qty = 1
# Trader S2: Job = Bid, Best Bid = 88, Best Ask = 150, Limit Price = 231
# Trader S2 generated order: Price = 89, Qty = 1
# Trader S3: Job = Bid, Best Bid = 86, Best Ask = 200, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 126, Best Ask = 228, Limit Price = 78
# Trader S4 generated order: Price = 227, Qty = 1
# Trader S5: Job = Ask, Best Bid = 134, Best Ask = 187, Limit Price = 68
# Trader S5 generated order: Price = 186, Qty = 1
# Trader S6: Job = Ask, Best Bid = 140, Best Ask = 221, Limit Price = 119
# Trader S6 generated order: Price = 220, Qty = 1
# Trader S7: Job = Bid, Best Bid = 147, Best Ask = 224, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 64, Best Ask = 236, Limit Price = 199
# Trader S8 generated order: Price = 65, Qty = 1
# Trader S9: Job = Ask, Best Bid = 51, Best Ask = 236, Limit Price = 62
# Trader S9 generated order: Price = 235, Qty = 1
# Trader B0: Job = Bid, Best Bid = 102, Best Ask = 228, Limit Price = 204
# Trader B0 generated order: Price = 103, Qty = 1
# Trader B1: Job = Ask, Best Bid = 59, Best Ask = 154, Limit Price = 59
# Trader B1 generated order: Price = 153, Qty = 1
# Trader B2: Job = Bid, Best Bid = 85, Best Ask = 232, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 117, Best Ask = 244, Limit Price = 173
# Trader B3 generated order: Price = 118, Qty = 1
# Trader B4: Job = Bid, Best Bid = 146, Best Ask = 214, Limit Price = 136
# Trader B4 generated order: Price = 136, Qty = 1
# Trader S0: Job = Ask, Best Bid = 83, Best Ask = 178, Limit Price = 147
# Trader S0 generated order: Price = 177, Qty = 1
# Trader S1: Job = Ask, Best Bid = 65, Best Ask = 166, Limit Price = 68
# Trader S1 generated order: Price = 165, Qty = 1
# Trader S2: Job = Bid, Best Bid = 132, Best Ask = 154, Limit Price = 231
# Trader S2 generated order: Price = 133, Qty = 1
# Trader S3: Job = Bid, Best Bid = 123, Best Ask = 195, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 132, Best Ask = 155, Limit Price = 78
# Trader S4 generated order: Price = 154, Qty = 1
# Trader S5: Job = Ask, Best Bid = 96, Best Ask = 231, Limit Price = 68
# Trader S5 generated order: Price = 230, Qty = 1
# Trader S6: Job = Ask, Best Bid = 145, Best Ask = 230, Limit Price = 119
# Trader S6 generated order: Price = 229, Qty = 1
# Trader S7: Job = Bid, Best Bid = 99, Best Ask = 187, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 86, Best Ask = 209, Limit Price = 199
# Trader S8 generated order: Price = 87, Qty = 1
# Trader S9: Job = Ask, Best Bid = 108, Best Ask = 170, Limit Price = 62
# Trader S9 generated order: Price = 169, Qty = 1
# Trader B0: Job = Bid, Best Bid = 147, Best Ask = 248, Limit Price = 204
# Trader B0 generated order: Price = 148, Qty = 1
# Trader B1: Job = Ask, Best Bid = 120, Best Ask = 180, Limit Price = 59
# Trader B1 generated order: Price = 179, Qty = 1
# Trader B2: Job = Bid, Best Bid = 102, Best Ask = 188, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 91, Best Ask = 190, Limit Price = 173
# Trader B3 generated order: Price = 92, Qty = 1
# Trader B4: Job = Bid, Best Bid = 125, Best Ask = 249, Limit Price = 136
# Trader B4 generated order: Price = 126, Qty = 1
# Trader S0: Job = Ask, Best Bid = 58, Best Ask = 214, Limit Price = 147
# Trader S0 generated order: Price = 213, Qty = 1
# Trader S1: Job = Ask, Best Bid = 127, Best Ask = 243, Limit Price = 68
# Trader S1 generated order: Price = 242, Qty = 1
# Trader S2: Job = Bid, Best Bid = 79, Best Ask = 215, Limit Price = 231
# Trader S2 generated order: Price = 80, Qty = 1
# Trader S3: Job = Bid, Best Bid = 104, Best Ask = 209, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 53, Best Ask = 152, Limit Price = 78
# Trader S4 generated order: Price = 151, Qty = 1
# Trader S5: Job = Ask, Best Bid = 147, Best Ask = 167, Limit Price = 68
# Trader S5 generated order: Price = 166, Qty = 1
# Trader S6: Job = Ask, Best Bid = 61, Best Ask = 170, Limit Price = 119
# Trader S6 generated order: Price = 169, Qty = 1
# Trader S7: Job = Bid, Best Bid = 52, Best Ask = 174, Limit Price = 65
# Trader S7 generated order: Price = 53, Qty = 1
# Trader S8: Job = Bid, Best Bid = 71, Best Ask = 170, Limit Price = 199
# Trader S8 generated order: Price = 72, Qty = 1
# Trader S9: Job = Ask, Best Bid = 72, Best Ask = 208, Limit Price = 62
# Trader S9 generated order: Price = 207, Qty = 1
# Trader B0: Job = Bid, Best Bid = 58, Best Ask = 162, Limit Price = 204
# Trader B0 generated order: Price = 59, Qty = 1
# Trader B1: Job = Ask, Best Bid = 112, Best Ask = 189, Limit Price = 59
# Trader B1 generated order: Price = 188, Qty = 1
# Trader B2: Job = Bid, Best Bid = 94, Best Ask = 195, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 69, Best Ask = 218, Limit Price = 173
# Trader B3 generated order: Price = 70, Qty = 1
# Trader B4: Job = Bid, Best Bid = 77, Best Ask = 222, Limit Price = 136
# Trader B4 generated order: Price = 78, Qty = 1
# Trader S0: Job = Ask, Best Bid = 82, Best Ask = 171, Limit Price = 147
# Trader S0 generated order: Price = 170, Qty = 1
# Trader S1: Job = Ask, Best Bid = 72, Best Ask = 238, Limit Price = 68
# Trader S1 generated order: Price = 237, Qty = 1
# Trader S2: Job = Bid, Best Bid = 54, Best Ask = 246, Limit Price = 231
# Trader S2 generated order: Price = 55, Qty = 1
# Trader S3: Job = Bid, Best Bid = 90, Best Ask = 193, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 59, Best Ask = 168, Limit Price = 78
# Trader S4 generated order: Price = 167, Qty = 1
# Trader S5: Job = Ask, Best Bid = 87, Best Ask = 150, Limit Price = 68
# Trader S5 generated order: Price = 149, Qty = 1
# Trader S6: Job = Ask, Best Bid = 54, Best Ask = 200, Limit Price = 119
# Trader S6 generated order: Price = 199, Qty = 1
# Trader S7: Job = Bid, Best Bid = 99, Best Ask = 234, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 127, Best Ask = 195, Limit Price = 199
# Trader S8 generated order: Price = 128, Qty = 1
# Trader S9: Job = Ask, Best Bid = 91, Best Ask = 159, Limit Price = 62
# Trader S9 generated order: Price = 158, Qty = 1
# Trader B0: Job = Bid, Best Bid = 91, Best Ask = 208, Limit Price = 204
# Trader B0 generated order: Price = 92, Qty = 1
# Trader B1: Job = Ask, Best Bid = 91, Best Ask = 222, Limit Price = 59
# Trader B1 generated order: Price = 221, Qty = 1
# Trader B2: Job = Bid, Best Bid = 58, Best Ask = 235, Limit Price = 65
# Trader B2 generated order: Price = 59, Qty = 1
# Trader B3: Job = Bid, Best Bid = 119, Best Ask = 204, Limit Price = 173
# Trader B3 generated order: Price = 120, Qty = 1
# Trader B4: Job = Bid, Best Bid = 128, Best Ask = 200, Limit Price = 136
# Trader B4 generated order: Price = 129, Qty = 1
# Trader S0: Job = Ask, Best Bid = 96, Best Ask = 171, Limit Price = 147
# Trader S0 generated order: Price = 170, Qty = 1
# Trader S1: Job = Ask, Best Bid = 55, Best Ask = 201, Limit Price = 68
# Trader S1 generated order: Price = 200, Qty = 1
# Trader S2: Job = Bid, Best Bid = 142, Best Ask = 226, Limit Price = 231
# Trader S2 generated order: Price = 143, Qty = 1
# Trader S3: Job = Bid, Best Bid = 148, Best Ask = 239, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 73, Best Ask = 190, Limit Price = 78
# Trader S4 generated order: Price = 189, Qty = 1
# Trader S5: Job = Ask, Best Bid = 118, Best Ask = 196, Limit Price = 68
# Trader S5 generated order: Price = 195, Qty = 1
# Trader S6: Job = Ask, Best Bid = 57, Best Ask = 165, Limit Price = 119
# Trader S6 generated order: Price = 164, Qty = 1
# Trader S7: Job = Bid, Best Bid = 127, Best Ask = 209, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 85, Best Ask = 181, Limit Price = 199
# Trader S8 generated order: Price = 86, Qty = 1
# Trader S9: Job = Ask, Best Bid = 145, Best Ask = 233, Limit Price = 62
# Trader S9 generated order: Price = 232, Qty = 1
# Trader B0: Job = Bid, Best Bid = 137, Best Ask = 150, Limit Price = 204
# Trader B0 generated order: Price = 138, Qty = 1
# Trader B1: Job = Ask, Best Bid = 62, Best Ask = 241, Limit Price = 59
# Trader B1 generated order: Price = 240, Qty = 1
# Trader B2: Job = Bid, Best Bid = 134, Best Ask = 170, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 134, Best Ask = 179, Limit Price = 173
# Trader B3 generated order: Price = 135, Qty = 1
# Trader B4: Job = Bid, Best Bid = 149, Best Ask = 194, Limit Price = 136
# Trader B4 generated order: Price = 136, Qty = 1
# Trader S0: Job = Ask, Best Bid = 79, Best Ask = 220, Limit Price = 147
# Trader S0 generated order: Price = 219, Qty = 1
# Trader S1: Job = Ask, Best Bid = 93, Best Ask = 187, Limit Price = 68
# Trader S1 generated order: Price = 186, Qty = 1
# Trader S2: Job = Bid, Best Bid = 149, Best Ask = 242, Limit Price = 231
# Trader S2 generated order: Price = 150, Qty = 1
# Trader S3: Job = Bid, Best Bid = 68, Best Ask = 243, Limit Price = 80
# Trader S3 generated order: Price = 69, Qty = 1
# Trader S4: Job = Ask, Best Bid = 122, Best Ask = 164, Limit Price = 78
# Trader S4 generated order: Price = 163, Qty = 1
# Trader S5: Job = Ask, Best Bid = 100, Best Ask = 246, Limit Price = 68
# Trader S5 generated order: Price = 245, Qty = 1
# Trader S6: Job = Ask, Best Bid = 109, Best Ask = 199, Limit Price = 119
# Trader S6 generated order: Price = 198, Qty = 1
# Trader S7: Job = Bid, Best Bid = 63, Best Ask = 185, Limit Price = 65
# Trader S7 generated order: Price = 64, Qty = 1
# Trader S8: Job = Bid, Best Bid = 57, Best Ask = 172, Limit Price = 199
# Trader S8 generated order: Price = 58, Qty = 1
# Trader S9: Job = Ask, Best Bid = 93, Best Ask = 151, Limit Price = 62
# Trader S9 generated order: Price = 150, Qty = 1
# Trader B0: Job = Bid, Best Bid = 110, Best Ask = 250, Limit Price = 204
# Trader B0 generated order: Price = 111, Qty = 1
# Trader B1: Job = Ask, Best Bid = 122, Best Ask = 182, Limit Price = 59
# Trader B1 generated order: Price = 181, Qty = 1
# Trader B2: Job = Bid, Best Bid = 85, Best Ask = 163, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 71, Best Ask = 166, Limit Price = 173
# Trader B3 generated order: Price = 72, Qty = 1
# Trader B4: Job = Bid, Best Bid = 84, Best Ask = 177, Limit Price = 136
# Trader B4 generated order: Price = 85, Qty = 1
# Trader S0: Job = Ask, Best Bid = 149, Best Ask = 217, Limit Price = 147
# Trader S0 generated order: Price = 216, Qty = 1
# Trader S1: Job = Ask, Best Bid = 105, Best Ask = 171, Limit Price = 68
# Trader S1 generated order: Price = 170, Qty = 1
# Trader S2: Job = Bid, Best Bid = 80, Best Ask = 239, Limit Price = 231
# Trader S2 generated order: Price = 81, Qty = 1
# Trader S3: Job = Bid, Best Bid = 121, Best Ask = 230, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 123, Best Ask = 234, Limit Price = 78
# Trader S4 generated order: Price = 233, Qty = 1
# Trader S5: Job = Ask, Best Bid = 118, Best Ask = 190, Limit Price = 68
# Trader S5 generated order: Price = 189, Qty = 1
# Trader S6: Job = Ask, Best Bid = 99, Best Ask = 187, Limit Price = 119
# Trader S6 generated order: Price = 186, Qty = 1
# Trader S7: Job = Bid, Best Bid = 101, Best Ask = 204, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 85, Best Ask = 179, Limit Price = 199
# Trader S8 generated order: Price = 86, Qty = 1
# Trader S9: Job = Ask, Best Bid = 61, Best Ask = 159, Limit Price = 62
# Trader S9 generated order: Price = 158, Qty = 1
# Trader B0: Job = Bid, Best Bid = 116, Best Ask = 155, Limit Price = 204
# Trader B0 generated order: Price = 117, Qty = 1
# Trader B1: Job = Ask, Best Bid = 106, Best Ask = 168, Limit Price = 59
# Trader B1 generated order: Price = 167, Qty = 1
# Trader B2: Job = Bid, Best Bid = 93, Best Ask = 156, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 145, Best Ask = 235, Limit Price = 173
# Trader B3 generated order: Price = 146, Qty = 1
# Trader B4: Job = Bid, Best Bid = 75, Best Ask = 248, Limit Price = 136
# Trader B4 generated order: Price = 76, Qty = 1
# Trader S0: Job = Ask, Best Bid = 90, Best Ask = 173, Limit Price = 147
# Trader S0 generated order: Price = 172, Qty = 1
# Trader S1: Job = Ask, Best Bid = 79, Best Ask = 156, Limit Price = 68
# Trader S1 generated order: Price = 155, Qty = 1
# Trader S2: Job = Bid, Best Bid = 148, Best Ask = 161, Limit Price = 231
# Trader S2 generated order: Price = 149, Qty = 1
# Trader S3: Job = Bid, Best Bid = 100, Best Ask = 151, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 145, Best Ask = 246, Limit Price = 78
# Trader S4 generated order: Price = 245, Qty = 1
# Trader S5: Job = Ask, Best Bid = 119, Best Ask = 190, Limit Price = 68
# Trader S5 generated order: Price = 189, Qty = 1
# Trader S6: Job = Ask, Best Bid = 136, Best Ask = 209, Limit Price = 119
# Trader S6 generated order: Price = 208, Qty = 1
# Trader S7: Job = Bid, Best Bid = 108, Best Ask = 169, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 105, Best Ask = 205, Limit Price = 199
# Trader S8 generated order: Price = 106, Qty = 1
# Trader S9: Job = Ask, Best Bid = 90, Best Ask = 220, Limit Price = 62
# Trader S9 generated order: Price = 219, Qty = 1
# Trader B0: Job = Bid, Best Bid = 91, Best Ask = 203, Limit Price = 204
# Trader B0 generated order: Price = 92, Qty = 1
# Trader B1: Job = Ask, Best Bid = 75, Best Ask = 187, Limit Price = 59
# Trader B1 generated order: Price = 186, Qty = 1
# Trader B2: Job = Bid, Best Bid = 100, Best Ask = 215, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 122, Best Ask = 188, Limit Price = 173
# Trader B3 generated order: Price = 123, Qty = 1
# Trader B4: Job = Bid, Best Bid = 112, Best Ask = 232, Limit Price = 136
# Trader B4 generated order: Price = 113, Qty = 1
# Trader S0: Job = Ask, Best Bid = 138, Best Ask = 173, Limit Price = 147
# Trader S0 generated order: Price = 172, Qty = 1
# Trader S1: Job = Ask, Best Bid = 111, Best Ask = 153, Limit Price = 68
# Trader S1 generated order: Price = 152, Qty = 1
# Trader S2: Job = Bid, Best Bid = 141, Best Ask = 217, Limit Price = 231
# Trader S2 generated order: Price = 142, Qty = 1
# Trader S3: Job = Bid, Best Bid = 67, Best Ask = 224, Limit Price = 80
# Trader S3 generated order: Price = 68, Qty = 1
# Trader S4: Job = Ask, Best Bid = 123, Best Ask = 194, Limit Price = 78
# Trader S4 generated order: Price = 193, Qty = 1
# Trader S5: Job = Ask, Best Bid = 148, Best Ask = 242, Limit Price = 68
# Trader S5 generated order: Price = 241, Qty = 1
# Trader S6: Job = Ask, Best Bid = 105, Best Ask = 211, Limit Price = 119
# Trader S6 generated order: Price = 210, Qty = 1
# Trader S7: Job = Bid, Best Bid = 84, Best Ask = 150, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 97, Best Ask = 228, Limit Price = 199
# Trader S8 generated order: Price = 98, Qty = 1
# Trader S9: Job = Ask, Best Bid = 81, Best Ask = 189, Limit Price = 62
# Trader S9 generated order: Price = 188, Qty = 1
# Trader B0: Job = Bid, Best Bid = 72, Best Ask = 247, Limit Price = 204
# Trader B0 generated order: Price = 73, Qty = 1
# Trader B1: Job = Ask, Best Bid = 97, Best Ask = 208, Limit Price = 59
# Trader B1 generated order: Price = 207, Qty = 1
# Trader B2: Job = Bid, Best Bid = 126, Best Ask = 246, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 71, Best Ask = 158, Limit Price = 173
# Trader B3 generated order: Price = 72, Qty = 1
# Trader B4: Job = Bid, Best Bid = 110, Best Ask = 191, Limit Price = 136
# Trader B4 generated order: Price = 111, Qty = 1
# Trader S0: Job = Ask, Best Bid = 74, Best Ask = 219, Limit Price = 147
# Trader S0 generated order: Price = 218, Qty = 1
# Trader S1: Job = Ask, Best Bid = 111, Best Ask = 237, Limit Price = 68
# Trader S1 generated order: Price = 236, Qty = 1
# Trader S2: Job = Bid, Best Bid = 132, Best Ask = 250, Limit Price = 231
# Trader S2 generated order: Price = 133, Qty = 1
# Trader S3: Job = Bid, Best Bid = 81, Best Ask = 202, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 62, Best Ask = 152, Limit Price = 78
# Trader S4 generated order: Price = 151, Qty = 1
# Trader S5: Job = Ask, Best Bid = 89, Best Ask = 217, Limit Price = 68
# Trader S5 generated order: Price = 216, Qty = 1
# Trader S6: Job = Ask, Best Bid = 60, Best Ask = 194, Limit Price = 119
# Trader S6 generated order: Price = 193, Qty = 1
# Trader S7: Job = Bid, Best Bid = 135, Best Ask = 151, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 81, Best Ask = 224, Limit Price = 199
# Trader S8 generated order: Price = 82, Qty = 1
# Trader S9: Job = Ask, Best Bid = 113, Best Ask = 197, Limit Price = 62
# Trader S9 generated order: Price = 196, Qty = 1
# Trader B0: Job = Bid, Best Bid = 56, Best Ask = 150, Limit Price = 204
# Trader B0 generated order: Price = 57, Qty = 1
# Trader B1: Job = Ask, Best Bid = 72, Best Ask = 155, Limit Price = 59
# Trader B1 generated order: Price = 154, Qty = 1
# Trader B2: Job = Bid, Best Bid = 141, Best Ask = 235, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 117, Best Ask = 203, Limit Price = 173
# Trader B3 generated order: Price = 118, Qty = 1
# Trader B4: Job = Bid, Best Bid = 121, Best Ask = 222, Limit Price = 136
# Trader B4 generated order: Price = 122, Qty = 1
# Trader S0: Job = Ask, Best Bid = 136, Best Ask = 225, Limit Price = 147
# Trader S0 generated order: Price = 224, Qty = 1
# Trader S1: Job = Ask, Best Bid = 61, Best Ask = 226, Limit Price = 68
# Trader S1 generated order: Price = 225, Qty = 1
# Trader S2: Job = Bid, Best Bid = 108, Best Ask = 219, Limit Price = 231
# Trader S2 generated order: Price = 109, Qty = 1
# Trader S3: Job = Bid, Best Bid = 117, Best Ask = 186, Limit Price = 80
# Trader S3 generated order: Price = 80, Qty = 1
# Trader S4: Job = Ask, Best Bid = 68, Best Ask = 165, Limit Price = 78
# Trader S4 generated order: Price = 164, Qty = 1
# Trader S5: Job = Ask, Best Bid = 61, Best Ask = 231, Limit Price = 68
# Trader S5 generated order: Price = 230, Qty = 1
# Trader S6: Job = Ask, Best Bid = 131, Best Ask = 249, Limit Price = 119
# Trader S6 generated order: Price = 248, Qty = 1
# Trader S7: Job = Bid, Best Bid = 64, Best Ask = 183, Limit Price = 65
# Trader S7 generated order: Price = 65, Qty = 1
# Trader S8: Job = Bid, Best Bid = 149, Best Ask = 246, Limit Price = 199
# Trader S8 generated order: Price = 150, Qty = 1
# Trader S9: Job = Ask, Best Bid = 79, Best Ask = 199, Limit Price = 62
# Trader S9 generated order: Price = 198, Qty = 1
# Trader B0: Job = Bid, Best Bid = 77, Best Ask = 151, Limit Price = 204
# Trader B0 generated order: Price = 78, Qty = 1
# Trader B1: Job = Ask, Best Bid = 119, Best Ask = 185, Limit Price = 59
# Trader B1 generated order: Price = 184, Qty = 1
# Trader B2: Job = Bid, Best Bid = 122, Best Ask = 218, Limit Price = 65
# Trader B2 generated order: Price = 65, Qty = 1
# Trader B3: Job = Bid, Best Bid = 135, Best Ask = 223, Limit Price = 173
# Trader B3 generated order: Price = 136, Qty = 1
# Trader B4: Job = Bid, Best Bid = 142, Best Ask = 216, Limit Price = 136
# ...
#  {'time': 27.016258612594235, 'tid': 'B2', 'price': 65, 'qty': 1},
#  {'time': 27.016258612594235, 'tid': 'B3', 'price': 72, 'qty': 1},
#  {'time': 27.016258612594235, 'tid': 'B4', 'price': 136, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'S0', 'price': 238, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'S1', 'price': 154, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'S2', 'price': 127, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'S3', 'price': 80, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'S4', 'price': 220, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'S5', 'price': 165, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'S6', 'price': 210, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'S7', 'price': 65, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'S8', 'price': 128, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'S9', 'price': 192, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'B0', 'price': 88, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'B1', 'price': 165, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'B2', 'price': 65, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'B3', 'price': 93, 'qty': 1},
#  {'time': 27.887474642901104, 'tid': 'B4', 'price': 66, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'S0', 'price': 161, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'S1', 'price': 193, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'S2', 'price': 151, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'S3', 'price': 80, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'S4', 'price': 184, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'S5', 'price': 176, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'S6', 'price': 163, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'S7', 'price': 65, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'S8', 'price': 118, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'S9', 'price': 187, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'B0', 'price': 83, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'B1', 'price': 156, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'B2', 'price': 65, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'B3', 'price': 66, 'qty': 1},
#  {'time': 28.400073522647467, 'tid': 'B4', 'price': 63, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'S0', 'price': 219, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'S1', 'price': 213, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'S2', 'price': 146, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'S3', 'price': 80, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'S4', 'price': 157, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'S5', 'price': 152, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'S6', 'price': 195, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'S7', 'price': 65, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'S8', 'price': 128, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'S9', 'price': 206, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'B0', 'price': 127, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'B1', 'price': 217, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'B2', 'price': 65, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'B3', 'price': 81, 'qty': 1},
#  {'time': 29.302621809480634, 'tid': 'B4', 'price': 77, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'S0', 'price': 161, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'S1', 'price': 171, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'S2', 'price': 148, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'S3', 'price': 80, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'S4', 'price': 185, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'S5', 'price': 154, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'S6', 'price': 194, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'S7', 'price': 65, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'S8', 'price': 104, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'S9', 'price': 178, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'B0', 'price': 100, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'B1', 'price': 156, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'B2', 'price': 65, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'B3', 'price': 96, 'qty': 1},
#  {'time': 29.451758950043523, 'tid': 'B4', 'price': 121, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'S0', 'price': 239, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'S1', 'price': 219, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'S2', 'price': 128, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'S3', 'price': 80, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'S4', 'price': 215, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'S5', 'price': 225, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'S6', 'price': 206, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'S7', 'price': 65, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'S8', 'price': 151, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'S9', 'price': 180, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'B0', 'price': 90, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'B1', 'price': 208, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'B2', 'price': 65, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'B3', 'price': 118, 'qty': 1},
#  {'time': 30.373056839146223, 'tid': 'B4', 'price': 53, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'S0', 'price': 230, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'S1', 'price': 225, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'S2', 'price': 101, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'S3', 'price': 63, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'S4', 'price': 219, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'S5', 'price': 236, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'S6', 'price': 168, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'S7', 'price': 65, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'S8', 'price': 70, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'S9', 'price': 149, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'B0', 'price': 119, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'B1', 'price': 168, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'B2', 'price': 52, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'B3', 'price': 144, 'qty': 1},
#  {'time': 30.85610882860525, 'tid': 'B4', 'price': 66, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'S0', 'price': 161, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'S1', 'price': 202, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'S2', 'price': 74, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'S3', 'price': 80, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'S4', 'price': 195, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'S5', 'price': 202, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'S6', 'price': 195, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'S7', 'price': 65, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'S8', 'price': 55, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'S9', 'price': 155, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'B0', 'price': 145, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'B1', 'price': 186, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'B2', 'price': 65, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'B3', 'price': 94, 'qty': 1},
#  {'time': 31.53455176479462, 'tid': 'B4', 'price': 118, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'S0', 'price': 187, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'S1', 'price': 246, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'S2', 'price': 77, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'S3', 'price': 80, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'S4', 'price': 178, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'S5', 'price': 193, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'S6', 'price': 154, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'S7', 'price': 65, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'S8', 'price': 129, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'S9', 'price': 204, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'B0', 'price': 76, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'B1', 'price': 211, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'B2', 'price': 64, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'B3', 'price': 54, 'qty': 1},
#  {'time': 31.57014182708937, 'tid': 'B4', 'price': 53, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'S0', 'price': 189, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'S1', 'price': 165, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'S2', 'price': 135, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'S3', 'price': 80, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'S4', 'price': 183, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'S5', 'price': 223, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'S6', 'price': 213, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'S7', 'price': 65, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'S8', 'price': 105, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'S9', 'price': 157, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'B0', 'price': 150, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'B1', 'price': 168, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'B2', 'price': 65, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'B3', 'price': 60, 'qty': 1},
#  {'time': 32.33006973808018, 'tid': 'B4', 'price': 136, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'S0', 'price': 226, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'S1', 'price': 215, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'S2', 'price': 146, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'S3', 'price': 80, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'S4', 'price': 187, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'S5', 'price': 210, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'S6', 'price': 184, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'S7', 'price': 59, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'S8', 'price': 133, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'S9', 'price': 233, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'B0', 'price': 149, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'B1', 'price': 192, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'B2', 'price': 60, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'B3', 'price': 114, 'qty': 1},
#  {'time': 32.76956701103859, 'tid': 'B4', 'price': 108, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'S0', 'price': 161, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'S1', 'price': 181, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'S2', 'price': 129, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'S3', 'price': 80, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'S4', 'price': 223, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'S5', 'price': 243, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'S6', 'price': 229, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'S7', 'price': 65, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'S8', 'price': 101, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'S9', 'price': 178, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'B0', 'price': 61, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'B1', 'price': 152, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'B2', 'price': 65, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'B3', 'price': 98, 'qty': 1},
#  {'time': 33.39370599420383, 'tid': 'B4', 'price': 95, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'S0', 'price': 243, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'S1', 'price': 215, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'S2', 'price': 112, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'S3', 'price': 80, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'S4', 'price': 207, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'S5', 'price': 195, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'S6', 'price': 157, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'S7', 'price': 65, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'S8', 'price': 88, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'S9', 'price': 171, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'B0', 'price': 149, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'B1', 'price': 228, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'B2', 'price': 65, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'B3', 'price': 131, 'qty': 1},
#  {'time': 33.70837457681403, 'tid': 'B4', 'price': 136, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'S0', 'price': 227, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'S1', 'price': 182, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'S2', 'price': 144, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'S3', 'price': 80, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'S4', 'price': 181, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'S5', 'price': 216, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'S6', 'price': 194, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'S7', 'price': 65, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'S8', 'price': 56, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'S9', 'price': 216, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'B0', 'price': 76, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'B1', 'price': 208, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'B2', 'price': 65, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'B3', 'price': 96, 'qty': 1},
#  {'time': 34.24257401390238, 'tid': 'B4', 'price': 72, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'S0', 'price': 207, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'S1', 'price': 154, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'S2', 'price': 126, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'S3', 'price': 75, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'S4', 'price': 212, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'S5', 'price': 230, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'S6', 'price': 157, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'S7', 'price': 65, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'S8', 'price': 126, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'S9', 'price': 182, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'B0', 'price': 128, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'B1', 'price': 244, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'B2', 'price': 65, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'B3', 'price': 118, 'qty': 1},
#  {'time': 34.31635685464613, 'tid': 'B4', 'price': 136, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'S0', 'price': 190, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'S1', 'price': 248, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'S2', 'price': 94, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'S3', 'price': 80, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'S4', 'price': 202, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'S5', 'price': 248, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'S6', 'price': 224, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'S7', 'price': 61, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'S8', 'price': 55, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'S9', 'price': 217, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'B0', 'price': 77, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'B1', 'price': 195, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'B2', 'price': 65, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'B3', 'price': 75, 'qty': 1},
#  {'time': 34.98720120934032, 'tid': 'B4', 'price': 55, 'qty': 1},
#  {'time': 35.63343093891039, 'tid': 'S0', 'price': 198, 'qty': 1},
#  {'time': 35.63343093891039, 'tid': 'S1', 'price': 151, 'qty': 1},
#  {'time': 35.63343093891039, 'tid': 'S2', 'price': 151, 'qty': 1},
#  {'time': 35.63343093891039, 'tid': 'S3', 'price': 80, 'qty': 1},
#  {'time': 35.63343093891039, 'tid': 'S4', 'price': 185, 'qty': 1},
#  {'time': 35.63343093891039, 'tid': 'S5', 'price': 249, 'qty': 1},
#  {'time': 35.63343093891039, 'tid': 'S6', 'price': 200, 'qty': 1},
#  {'time': 35.63343093891039, 'tid': 'S7', 'price': 65, 'qty': 1},
#  {'time': 35.63343093891039, 'tid': 'S8', 'price': 100, 'qty': 1},
#  {'time': 35.63343093891039, 'tid': 'S9', 'price': 242, 'qty': 1},
#  ...]

# %% [markdown]
# # Explanation

# %% [markdown]
# The code simulates a basic market environment where traders, represented by the Trader_ZIP class, generate buy or sell orders based on their roles (buyer or seller) and market conditions. Each Trader_ZIP instance is initialized with a unique ID, balance, a randomly assigned limit price (the maximum or minimum price they are willing to buy or sell at), and either a 'Bid' or 'Ask' role. The class also includes genetic algorithm (GA) parameters and a margin value that influences pricing strategies. During the market session, traders generate orders based on the best bid and ask prices from the Limit Order Book (LOB), ensuring their offers are competitive yet within their limit prices. After a trade, the trader adapts their strategy by adjusting the margin, becoming more aggressive if successful or more conservative if not, while the GA helps evolve strategies over time by combining and mutating parent strategies. The market session, defined by start and end times, runs in a loop where traders generate orders at each time step based on current LOB conditions, and the trades are recorded in a tape. If enabled, the tape of trades is printed at the session's end. The supply and demand schedules define price ranges for market activity, though they aren't deeply integrated into this simulation. The output logs all trades, providing insight into how traders interact under various conditions and demonstrating the effectiveness of the simple GA-based adaptation mechanism.

# %% [markdown]
# # Output

# %% [markdown]
# The output log of orders generated by traders in the market simulation highlights the decisions made by each trader throughout the simulation, providing insights into their behavior and the market's functioning. Each trader is randomly assigned a role as either a buyer (Bid) or seller (Ask), determining whether they will generate a bid or ask order. The system logs the current best bid and ask prices from the Limit Order Book (LOB), each trader's limit price (the maximum price a buyer will pay or the minimum a seller will accept), the generated order's price, and the order quantity, which is consistently set to 1 for simplicity. For buyers, the price is set just above the current best bid without exceeding the limit price, while for sellers, it is set just below the best ask, staying above the limit price. Traders may adapt their strategies after generating orders, with successful trades potentially leading to more aggressive or conservative future bids or asks. The diversity in bid and ask prices across traders reflects the random initialization of limit prices and varying LOB conditions. The interaction between the best bid and ask prices and traders' decisions creates dynamic price fluctuations, with some orders closely matching LOB prices while others diverge due to differing limit prices. This output shows that the market simulation functions as intended, with traders making decisions influenced by their roles, the LOB, and their limit prices. The traders actively engage in the market, generating valid prices and demonstrating an adaptive behavior that could lead to improved strategies. Further exploration could involve increasing the complexity of the adaptation mechanism, such as more rigorous application of the genetic algorithm, and analyzing the impact of different trader proportions on market dynamics.
